# %%
from net.st_gcn import Model
import torch

# %%
# Cấu hình graph
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

graph_args = {'layout': 'emotion_walk', 'strategy': 'uniform'}

model = Model(
    in_channels=3,          # XYZ
    num_class= 4 ,
    graph_args=graph_args,
    edge_importance_weighting=True
).to(device)

# %%
model
# Out:
# Model(
#   (data_bn): BatchNorm1d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (st_gcn_networks): ModuleList(
#     (0): st_gcn(
#       (gcn): ConvTemporalGraphical(
#         (conv): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (tcn): Sequential(
#         (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(64, 64, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): Dropout(p=0, inplace=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (1-3): 3 x st_gcn(
#       (gcn): ConvTemporalGraphical(
#         (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (tcn): Sequential(
#         (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(64, 64, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): Dropout(p=0, inplace=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (4): st_gcn(
#       (gcn): ConvTemporalGraphical(
#         (conv): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (tcn): Sequential(
#         (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(128, 128, kernel_size=(9, 1), stride=(2, 1), padding=(4, 0))
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): Dropout(p=0, inplace=True)
#       )
#       (residual): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 1))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (5-6): 2 x st_gcn(
#       (gcn): ConvTemporalGraphical(
#         (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (tcn): Sequential(
#         (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(128, 128, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): Dropout(p=0, inplace=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (7): st_gcn(
#       (gcn): ConvTemporalGraphical(
#         (conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (tcn): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(256, 256, kernel_size=(9, 1), stride=(2, 1), padding=(4, 0))
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): Dropout(p=0, inplace=True)
#       )
#       (residual): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 1))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (8-9): 2 x st_gcn(
#       (gcn): ConvTemporalGraphical(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (tcn): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): Conv2d(256, 256, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): Dropout(p=0, inplace=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (edge_importance): ParameterList(
#       (0): Parameter containing: [torch.float32 of size 1x16x16 (cuda:0)]
#       (1): Parameter containing: [torch.float32 of size 1x16x16 (cuda:0)]
#       (2): Parameter containing: [torch.float32 of size 1x16x16 (cuda:0)]
#       (3): Parameter containing: [torch.float32 of size 1x16x16 (cuda:0)]
#       (4): Parameter containing: [torch.float32 of size 1x16x16 (cuda:0)]
#       (5): Parameter containing: [torch.float32 of size 1x16x16 (cuda:0)]
#       (6): Parameter containing: [torch.float32 of size 1x16x16 (cuda:0)]
#       (7): Parameter containing: [torch.float32 of size 1x16x16 (cuda:0)]
#       (8): Parameter containing: [torch.float32 of size 1x16x16 (cuda:0)]
#       (9): Parameter containing: [torch.float32 of size 1x16x16 (cuda:0)]
#   )
#   (fcn): Conv2d(256, 4, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
import get_data
data_path = "data/Data.h5"
label_path = "data/Labels_My.h5"  # chỉnh đúng đường dẫn
Gait = get_data.get_data(data_path)
Labels = get_data.get_labels(label_path)
# Out:
# Số dataset đã lấy: 672
# Kích thước mảng cuối cùng: (672, 30, 48)
# Tổng giá trị hàng 1 của tất cả dataset gộp lại:
# (672,)

# %%
X = Gait
y = Labels

# %%
from torch.utils.data import TensorDataset, DataLoader
import numpy as np
from sklearn.model_selection import train_test_split

# Giả sử X là numpy array (672, 30, 48)
N, T, total_features = X.shape
V, C = 16, 3

# Reshape sang (N, T, V, C)
X_reshaped = X.reshape(N, T, V, C)

# Split dữ liệu numpy
X_train_np, X_test_np, y_train_np, y_test_np = train_test_split(
    X_reshaped, y, test_size=0.2, random_state=42, shuffle=True)

# Chuyển sang tensor và permute + thêm chiều M
def preprocess_input(x_np):
    x_tensor = torch.tensor(x_np, dtype=torch.float32)
    x_perm = x_tensor.permute(0, 3, 1, 2)  # [N, C, T, V]
    x_final = x_perm.unsqueeze(-1)          # [N, C, T, V, M=1]
    return x_final

X_train_tensor = preprocess_input(X_train_np)
X_test_tensor = preprocess_input(X_test_np)

y_train_tensor = torch.tensor(y_train_np, dtype=torch.long)
y_test_tensor = torch.tensor(y_test_np, dtype=torch.long)

train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# %%
import torch.nn as nn
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

for epoch in range(200):  # ví dụ 20 epochs
    model.train()
    total_loss = 0
    correct = 0
    total = 0

    for X_batch, y_batch in train_loader:
        X_batch = X_batch.to(device)
        y_batch = y_batch.to(device)

        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        _, predicted = outputs.max(1)
        correct += predicted.eq(y_batch).sum().item()
        total += y_batch.size(0)

    acc = 100. * correct / total
    print(f"Epoch {epoch+1}, Loss: {total_loss:.4f}, Accuracy: {acc:.2f}%")
# Out:
# Epoch 1, Loss: 21.4266, Accuracy: 75.42%
# Epoch 2, Loss: 14.8099, Accuracy: 83.99%
# Epoch 3, Loss: 14.4835, Accuracy: 83.24%
# Epoch 4, Loss: 11.8976, Accuracy: 89.20%
# Epoch 5, Loss: 13.9170, Accuracy: 84.36%
# Epoch 6, Loss: 11.7279, Accuracy: 87.52%
# Epoch 7, Loss: 10.4141, Accuracy: 90.13%
# Epoch 8, Loss: 9.3884, Accuracy: 89.76%
# Epoch 9, Loss: 8.9480, Accuracy: 90.50%
# Epoch 10, Loss: 11.7217, Accuracy: 88.08%
# Epoch 11, Loss: 9.8430, Accuracy: 89.20%
# Epoch 12, Loss: 8.2304, Accuracy: 91.43%
# Epoch 13, Loss: 6.6731, Accuracy: 92.55%
# Epoch 14, Loss: 9.0016, Accuracy: 90.69%
# Epoch 15, Loss: 9.5336, Accuracy: 92.36%
# Epoch 16, Loss: 7.8840, Accuracy: 91.81%
# Epoch 17, Loss: 10.1773, Accuracy: 88.08%
# Epoch 18, Loss: 9.9905, Accuracy: 90.32%
# Epoch 19, Loss: 8.0206, Accuracy: 91.99%
# Epoch 20, Loss: 6.0859, Accuracy: 93.30%
# Epoch 21, Loss: 3.2410, Accuracy: 97.39%
# Epoch 22, Loss: 5.2670, Accuracy: 95.34%
# Epoch 23, Loss: 5.1461, Accuracy: 94.79%
# Epoch 24, Loss: 4.8144, Accuracy: 95.53%
# Epoch 25, Loss: 6.2937, Accuracy: 93.30%
# Epoch 26, Loss: 7.1345, Accuracy: 93.30%
# Epoch 27, Loss: 5.0859, Accuracy: 94.04%
# Epoch 28, Loss: 5.8905, Accuracy: 93.11%
# Epoch 29, Loss: 4.0597, Accuracy: 96.83%
# Epoch 30, Loss: 5.3212, Accuracy: 94.97%
# Epoch 31, Loss: 6.4154, Accuracy: 93.30%
# Epoch 32, Loss: 4.5112, Accuracy: 95.16%
# Epoch 33, Loss: 3.8707, Accuracy: 95.72%
# Epoch 34, Loss: 4.5371, Accuracy: 95.72%
# Epoch 35, Loss: 4.7193, Accuracy: 94.97%
# Epoch 36, Loss: 3.9348, Accuracy: 95.34%
# Epoch 37, Loss: 4.1447, Accuracy: 96.09%
# Epoch 38, Loss: 8.6449, Accuracy: 93.67%
# Epoch 39, Loss: 8.2103, Accuracy: 91.99%
# Epoch 40, Loss: 6.2041, Accuracy: 94.23%
# Epoch 41, Loss: 3.9921, Accuracy: 95.72%
# Epoch 42, Loss: 2.4080, Accuracy: 97.95%
# Epoch 43, Loss: 3.3054, Accuracy: 97.21%
# Epoch 44, Loss: 5.5157, Accuracy: 94.41%
# Epoch 45, Loss: 4.6855, Accuracy: 93.67%
# Epoch 155, Loss: 4.9712, Accuracy: 94.41%
# Epoch 156, Loss: 2.9044, Accuracy: 97.39%
# Epoch 157, Loss: 3.3588, Accuracy: 97.21%
# Epoch 158, Loss: 2.7595, Accuracy: 97.58%
# Epoch 159, Loss: 1.5843, Accuracy: 98.14%
# Epoch 160, Loss: 1.9180, Accuracy: 98.51%
# Epoch 161, Loss: 1.9433, Accuracy: 97.95%
# Epoch 162, Loss: 1.9179, Accuracy: 97.58%
# Epoch 163, Loss: 0.6337, Accuracy: 99.63%
# Epoch 164, Loss: 2.4204, Accuracy: 97.95%
# Epoch 165, Loss: 1.7730, Accuracy: 98.32%
# Epoch 166, Loss: 0.4095, Accuracy: 99.81%
# Epoch 167, Loss: 0.9503, Accuracy: 99.07%
# Epoch 168, Loss: 0.4741, Accuracy: 99.63%
# Epoch 169, Loss: 1.6098, Accuracy: 98.14%
# Epoch 170, Loss: 2.5081, Accuracy: 97.21%
# Epoch 171, Loss: 1.0900, Accuracy: 98.88%
# Epoch 172, Loss: 0.4391, Accuracy: 99.63%
# Epoch 173, Loss: 2.6782, Accuracy: 96.83%
# Epoch 174, Loss: 2.6306, Accuracy: 97.39%
# Epoch 175, Loss: 1.1595, Accuracy: 98.14%
# Epoch 176, Loss: 0.2785, Accuracy: 99.81%
# Epoch 177, Loss: 0.4823, Accuracy: 99.63%
# Epoch 178, Loss: 0.9490, Accuracy: 99.44%
# Epoch 179, Loss: 4.5671, Accuracy: 97.58%
# Epoch 180, Loss: 2.7620, Accuracy: 97.77%
# Epoch 181, Loss: 1.9118, Accuracy: 98.14%
# Epoch 182, Loss: 1.7175, Accuracy: 97.95%
# Epoch 183, Loss: 1.1176, Accuracy: 98.70%
# Epoch 184, Loss: 0.6316, Accuracy: 99.26%
# Epoch 185, Loss: 0.4112, Accuracy: 99.44%
# Epoch 186, Loss: 1.1636, Accuracy: 98.88%
# Epoch 187, Loss: 0.5868, Accuracy: 99.07%
# Epoch 188, Loss: 0.3440, Accuracy: 99.63%
# Epoch 189, Loss: 0.1718, Accuracy: 100.00%
# Epoch 190, Loss: 0.0645, Accuracy: 100.00%
# Epoch 191, Loss: 0.1561, Accuracy: 99.81%
# Epoch 192, Loss: 0.2274, Accuracy: 99.81%
# Epoch 193, Loss: 0.2105, Accuracy: 100.00%
# Epoch 194, Loss: 0.1579, Accuracy: 100.00%
# Epoch 195, Loss: 0.1623, Accuracy: 99.81%
# Epoch 196, Loss: 0.0840, Accuracy: 100.00%
# Epoch 197, Loss: 0.6680, Accuracy: 98.88%
# Epoch 198, Loss: 0.7759, Accuracy: 99.07%
# Epoch 199, Loss: 1.1489, Accuracy: 98.88%
# Epoch 200, Loss: 1.1676, Accuracy: 98.70%

# %%
model.eval()  # Chuyển model sang chế độ đánh giá (eval)
correct = 0
total = 0
with torch.no_grad():  # Không tính gradient khi test, tiết kiệm bộ nhớ
    for X_batch, y_batch in test_loader:
        X_batch = X_batch.to(device)
        y_batch = y_batch.to(device)

        outputs = model(X_batch)
        _, predicted = outputs.max(1)
        correct += predicted.eq(y_batch).sum().item()
        total += y_batch.size(0)

test_acc = 100. * correct / total
print(f"Test Accuracy: {test_acc:.2f}%")
# Out:
# Test Accuracy: 94.81%

# %%
test_loader
